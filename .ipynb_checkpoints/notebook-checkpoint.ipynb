# %%
# Kiran in ONN

# %%
import pandas as pd

# %%
df = pd.read_excel("BhuNirvighna_Land_Acquisition_Dataset.xlsx")

# %%
df.head()
# Out:
#    Project_ID           State   District       Project_Type  \
# 0  BHNV-00001     West Bengal    Hooghly         Irrigation
# 1  BHNV-00002  Madhya Pradesh     Ujjain  Urban Development
# 2  BHNV-00003          Odisha  Sambalpur  Urban Development
# 3  BHNV-00004         Gujarat  Ahmedabad            Railway
# 4  BHNV-00005     West Bengal    Kolkata         Irrigation
#
#    Land_Required_Hectare  Land_Acquired_Hectare  Affected_Families  \
# 0                 169.36                 107.95                304
# 1                  60.51                  57.81                 94
# 2                  84.41                  33.67                164
# 3                  68.02                  46.03                129
# 4                  29.96                  23.30                 48
#
#    Displaced_Families Sanction_Date 3A_Notification_Date  ...  \
# 0                  50    2019-05-03           2019-08-29  ...
# 1                  15    2021-04-29           2023-02-26  ...
# 2                  26    2018-11-25           2019-12-18  ...
# 3                  24    2018-07-05           2019-05-16  ...
# 4                   8    2022-03-02           2023-01-22  ...
#
#   Compensation_Amount_Crore RR_Amount_Crore Compensation_Status  \
# 0                    207.80           13.46      Partially paid
# 1                    124.42            6.28         Mostly paid
# 2                    214.35           10.61             Pending
# 3                    223.83           11.34      Partially paid
# 4                     53.02            5.04      Partially paid
#
#   R&R_Progress_Percent  Legal_Disputes_Count       Possession_Status  \
# 0                 97.7                     4                 Pending
# 1                 93.8                     4  Substantially complete
# 2                100.0                     4                 Pending
# 3                100.0                     1      Partial possession
# 4                 86.7                     1      Partial possession
#
#   Historical_Delay_Days  Risk_Score_0_100  Delay_Label  \
# 0                   736                58            0
# 1                  1745                49            0
# 2                  2240                68            1
# 3                   602                57            0
# 4                  1438                56            0
#
#                                           Data_Basis
# 0  Synthetic prototype; fields modeled on public ...
# 1  Synthetic prototype; fields modeled on public ...
# 2  Synthetic prototype; fields modeled on public ...
# 3  Synthetic prototype; fields modeled on public ...
# 4  Synthetic prototype; fields modeled on public ...
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (2000, 24)

# %%
df.to_csv("BhuNirvighna_Land_Acquisition_Dataset.csv", index=False)

# %%
check = pd.read_csv("BhuNirvighna_Land_Acquisition_Dataset.csv")
check.head()
# Out:
#    Project_ID           State   District       Project_Type  \
# 0  BHNV-00001     West Bengal    Hooghly         Irrigation
# 1  BHNV-00002  Madhya Pradesh     Ujjain  Urban Development
# 2  BHNV-00003          Odisha  Sambalpur  Urban Development
# 3  BHNV-00004         Gujarat  Ahmedabad            Railway
# 4  BHNV-00005     West Bengal    Kolkata         Irrigation
#
#    Land_Required_Hectare  Land_Acquired_Hectare  Affected_Families  \
# 0                 169.36                 107.95                304
# 1                  60.51                  57.81                 94
# 2                  84.41                  33.67                164
# 3                  68.02                  46.03                129
# 4                  29.96                  23.30                 48
#
#    Displaced_Families Sanction_Date 3A_Notification_Date  ...  \
# 0                  50    2019-05-03           2019-08-29  ...
# 1                  15    2021-04-29           2023-02-26  ...
# 2                  26    2018-11-25           2019-12-18  ...
# 3                  24    2018-07-05           2019-05-16  ...
# 4                   8    2022-03-02           2023-01-22  ...
#
#   Compensation_Amount_Crore RR_Amount_Crore Compensation_Status  \
# 0                    207.80           13.46      Partially paid
# 1                    124.42            6.28         Mostly paid
# 2                    214.35           10.61             Pending
# 3                    223.83           11.34      Partially paid
# 4                     53.02            5.04      Partially paid
#
#   R&R_Progress_Percent  Legal_Disputes_Count       Possession_Status  \
# 0                 97.7                     4                 Pending
# 1                 93.8                     4  Substantially complete
# 2                100.0                     4                 Pending
# 3                100.0                     1      Partial possession
# 4                 86.7                     1      Partial possession
#
#   Historical_Delay_Days  Risk_Score_0_100  Delay_Label  \
# 0                   736                58            0
# 1                  1745                49            0
# 2                  2240                68            1
# 3                   602                57            0
# 4                  1438                56            0
#
#                                           Data_Basis
# 0  Synthetic prototype; fields modeled on public ...
# 1  Synthetic prototype; fields modeled on public ...
# 2  Synthetic prototype; fields modeled on public ...
# 3  Synthetic prototype; fields modeled on public ...
# 4  Synthetic prototype; fields modeled on public ...
#
# [5 rows x 24 columns]

# %%
df = pd.read_excel(r"BhuNirvighna_Land_Acquisition_Dataset.xlsx")

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\hp\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\hp\anaconda3\lib\site-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/raw/BhuNirvighna_Land_Acquisition_Dataset.csv")
df.head()
# Out:
#    Project_ID           State   District       Project_Type  \
# 0  BHNV-00001     West Bengal    Hooghly         Irrigation
# 1  BHNV-00002  Madhya Pradesh     Ujjain  Urban Development
# 2  BHNV-00003          Odisha  Sambalpur  Urban Development
# 3  BHNV-00004         Gujarat  Ahmedabad            Railway
# 4  BHNV-00005     West Bengal    Kolkata         Irrigation
#
#    Land_Required_Hectare  Land_Acquired_Hectare  Affected_Families  \
# 0                 169.36                 107.95                304
# 1                  60.51                  57.81                 94
# 2                  84.41                  33.67                164
# 3                  68.02                  46.03                129
# 4                  29.96                  23.30                 48
#
#    Displaced_Families Sanction_Date 3A_Notification_Date  ...  \
# 0                  50    2019-05-03           2019-08-29  ...
# 1                  15    2021-04-29           2023-02-26  ...
# 2                  26    2018-11-25           2019-12-18  ...
# 3                  24    2018-07-05           2019-05-16  ...
# 4                   8    2022-03-02           2023-01-22  ...
#
#   Compensation_Amount_Crore RR_Amount_Crore Compensation_Status  \
# 0                    207.80           13.46      Partially paid
# 1                    124.42            6.28         Mostly paid
# 2                    214.35           10.61             Pending
# 3                    223.83           11.34      Partially paid
# 4                     53.02            5.04      Partially paid
#
#   R&R_Progress_Percent  Legal_Disputes_Count       Possession_Status  \
# 0                 97.7                     4                 Pending
# 1                 93.8                     4  Substantially complete
# 2                100.0                     4                 Pending
# 3                100.0                     1      Partial possession
# 4                 86.7                     1      Partial possession
#
#   Historical_Delay_Days  Risk_Score_0_100  Delay_Label  \
# 0                   736                58            0
# 1                  1745                49            0
# 2                  2240                68            1
# 3                   602                57            0
# 4                  1438                56            0
#
#                                           Data_Basis
# 0  Synthetic prototype; fields modeled on public ...
# 1  Synthetic prototype; fields modeled on public ...
# 2  Synthetic prototype; fields modeled on public ...
# 3  Synthetic prototype; fields modeled on public ...
# 4  Synthetic prototype; fields modeled on public ...
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (2000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Project_ID                 2000 non-null   object
#  1   State                      2000 non-null   object
#  2   District                   2000 non-null   object
#  3   Project_Type               2000 non-null   object
#  4   Land_Required_Hectare      2000 non-null   float64
#  5   Land_Acquired_Hectare      2000 non-null   float64
#  6   Affected_Families          2000 non-null   int64
#  7   Displaced_Families         2000 non-null   int64
#  8   Sanction_Date              2000 non-null   object
#  9   3A_Notification_Date       2000 non-null   object
#  10  3D_Notification_Date       2000 non-null   object
#  11  Award_Date                 2000 non-null   object
#  12  Payment_Date               2000 non-null   object
#  13  Possession_Date            2000 non-null   object
#  14  Compensation_Amount_Crore  2000 non-null   float64
#  15  RR_Amount_Crore            2000 non-null   float64
#  16  Compensation_Status        2000 non-null   object
#  17  R&R_Progress_Percent       2000 non-null   float64
#  18  Legal_Disputes_Count       2000 non-null   int64
#  19  Possession_Status          2000 non-null   object
#  20  Historical_Delay_Days      2000 non-null   int64
#  21  Risk_Score_0_100           2000 non-null   int64
#  22  Delay_Label                2000 non-null   int64
#  23  Data_Basis                 2000 non-null   object
# dtypes: float64(5), int64(6), object(13)
# memory usage: 375.1+ KB

# %%
df.isnull().sum()
# Out:
# Project_ID                   0
# State                        0
# District                     0
# Project_Type                 0
# Land_Required_Hectare        0
# Land_Acquired_Hectare        0
# Affected_Families            0
# Displaced_Families           0
# Sanction_Date                0
# 3A_Notification_Date         0
# 3D_Notification_Date         0
# Award_Date                   0
# Payment_Date                 0
# Possession_Date              0
# Compensation_Amount_Crore    0
# RR_Amount_Crore              0
# Compensation_Status          0
# R&R_Progress_Percent         0
# Legal_Disputes_Count         0
# Possession_Status            0
# Historical_Delay_Days        0
# Risk_Score_0_100             0
# Delay_Label                  0
# Data_Basis                   0
# dtype: int64

# %%
date_cols = ['Sanction_Date','3A_Notification_Date','3D_Notification_Date',
             'Award_Date','Payment_Date','Possession_Date']
for c in date_cols:
    df[c] = pd.to_datetime(df[c])

# %%
# Flag rows where dates are out of logical order

df['date_issue'] = (
    (df['3D_Notification_Date'] < df['3A_Notification_Date']) |
    (df['Award_Date'] < df['3D_Notification_Date'])
)
print(df['date_issue'].sum(), "rows have date order issues")
# Out:
# 1033 rows have date order issues

# %%
# drop them for clean training

df_clean = df[~df['date_issue']].copy()

# %%
# Save cleaned data
df_clean.to_csv("data/cleaned/cleaned_data.csv", index=False)

# %%
# Visualss

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set_style("whitegrid")
os.makedirs("visuals", exist_ok=True)

# %%
# Delay Rate by Compensation Status


plt.figure(figsize=(7,5))

comp_delay = df_clean.groupby('Compensation_Status')['Delay_Label'].mean().sort_values() * 100
sns.barplot(x=comp_delay.index, y=comp_delay.values, hue=comp_delay.index, palette="Reds", legend=False)

plt.title("Delay Rate by Compensation Status", fontsize=14, fontweight='bold')

plt.ylabel("Delay Rate (%)")
plt.xlabel("Compensation Status")

plt.tight_layout()
plt.savefig("visuals/01_delay_by_compensation_status.png", dpi=200)

plt.show()

# %%
# Delay Rate by Possession Status

plt.figure(figsize=(7,5))
poss_delay = df_clean.groupby('Possession_Status')['Delay_Label'].mean().sort_values() * 100
sns.barplot(x=poss_delay.index, y=poss_delay.values, hue=poss_delay.index, palette="Oranges", legend=False)
plt.title("Delay Rate by Possession Status", fontsize=14, fontweight='bold')
plt.ylabel("Delay Rate (%)")
plt.xlabel("Possession Status")
plt.tight_layout()
plt.savefig("visuals/02_delay_by_possession_status.png", dpi=200)
plt.show()

# %%
# Risk Score Distribution

plt.figure(figsize=(7,5))

sns.histplot(df_clean['Risk_Score_0_100'], bins=30, kde=True, color="#2b2d76")
plt.title("Distribution of Risk Scores", fontsize=14, fontweight='bold')


plt.xlabel("Risk Score (0-100)")
plt.ylabel("Number of Projects")

plt.tight_layout()
plt.savefig("visuals/03_risk_score_distribution.png", dpi=200)
plt.show()

# %%
# Delay Rate by Project Type
plt.figure(figsize=(8,5))
type_delay = df_clean.groupby('Project_Type')['Delay_Label'].mean().sort_values() * 100
sns.barplot(x=type_delay.values, y=type_delay.index, hue=type_delay.index, palette="Blues_r", legend=False)

plt.title("Delay Rate by Project Type", fontsize=14, fontweight='bold')
plt.xlabel("Delay Rate (%)")
plt.ylabel("Project Type")

plt.tight_layout()

plt.savefig("visuals/04_delay_by_project_type.png", dpi=200)
plt.show()

# %%
# Correlation Heatmap

plt.figure(figsize=(9,7))
num_cols = ['Land_Required_Hectare','Land_Acquired_Hectare','Affected_Families',
            'Displaced_Families','Compensation_Amount_Crore','RR_Amount_Crore',
            'R&R_Progress_Percent','Legal_Disputes_Count','Historical_Delay_Days',
            'Risk_Score_0_100']


corr = df_clean[num_cols].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", center=0, linewidths=0.5)

plt.title("Correlation Heatmap of Numeric Features", fontsize=14, fontweight='bold')

plt.tight_layout()


plt.savefig("visuals/05_correlation_heatmap.png", dpi=200)
plt.show()

# %%
# Legal Disputes vs Delay

plt.figure(figsize=(7,5))
sns.boxplot(x='Delay_Label', y='Legal_Disputes_Count', data=df_clean, hue='Delay_Label', palette="Set2", legend=False)
plt.title("Legal Disputes Count vs Delay Outcome", fontsize=14, fontweight='bold')
plt.xlabel("Delay Label (0 = On-Time, 1 = Delayed)")
plt.ylabel("Number of Legal Disputes")
plt.tight_layout()
plt.savefig("visuals/06_legal_disputes_vs_delay.png", dpi=200)
plt.show()

# %%
# Project Outcome Distribution

plt.figure(figsize=(7,7))
counts = df_clean['Delay_Label'].value_counts().sort_index()

labels = ['On-Time', 'Delayed']
colors = ['#4a7a1e', '#a43b3b']
explode = (0, 0.06)

plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=colors, explode=explode, textprops={'fontsize':13, 'fontweight':'bold'},
        wedgeprops={'edgecolor':'white','linewidth':1.5})

plt.title('Project Outcome Distribution', fontsize=15, fontweight='bold')
plt.tight_layout()

plt.savefig("visuals/07_delay_pie_chart.png", dpi=200)
plt.show()

# %%
plt.figure(figsize=(7,7))
counts = df_clean['Delay_Label'].value_counts().sort_index()
labels = ['On-Time', 'Delayed']
edge_colors = ['#4a7a1e', '#a43b3b']
explode = (0, 0.06)

wedges, texts, autotexts = plt.pie(
    counts, labels=labels, autopct='%1.1f%%', startangle=90,
    explode=explode, textprops={'fontsize':13, 'fontweight':'bold'},
    wedgeprops={'linewidth':2.5}
)

# Remove fill, keep only colored border per wedge
for wedge, color in zip(wedges, edge_colors):
    wedge.set_facecolor('none')
    wedge.set_edgecolor(color)

for autotext, color in zip(autotexts, edge_colors):
    autotext.set_color(color)

plt.title('Project Outcome Distribution', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig("visuals/07_delay_pie_chart_outline.png", dpi=200, transparent=True)
plt.show()

# %%
# Feasibility & Viability Radar Chart

import numpy as np

# Feasibility dimensions — matches your proposal's Feasibility Scorecard
categories = ['Data\nAvailability', 'Technical\nFeasibility', 'Time-to-\nPrototype',
              'Team Skill\nMatch', 'Explainability\nReadiness', 'Scalability']
scores = [9, 7, 9, 8, 6, 7]  # out of 10

N = len(categories)

angles = np.linspace(0, 2*np.pi, N, endpoint=False).tolist()
scores_plot = scores + scores[:1]
angles_plot = angles + angles[:1]

fig, ax = plt.subplots(figsize=(7,7), subplot_kw=dict(polar=True))

ax.plot(angles_plot, scores_plot, color='#2b2d76', linewidth=2.5)
ax.fill(angles_plot, scores_plot, color='#2b2d76', alpha=0.25)



ax.set_xticks(angles)
ax.set_xticklabels(categories, fontsize=11, fontweight='bold')
ax.set_ylim(0, 10)
ax.set_yticks([2,4,6,8,10])
ax.set_yticklabels(['2','4','6','8','10'], fontsize=9, color='gray')
ax.set_rlabel_position(20)



# Mark each point with its score
for angle, score in zip(angles, scores):
    ax.annotate(str(score), xy=(angle, score), xytext=(angle, score+0.7),
                fontsize=10, fontweight='bold', color='#b5871a', ha='center')

plt.title('Feasibility & Viability Assessment', fontsize=15, fontweight='bold', pad=30)
plt.tight_layout()


plt.savefig("visuals/08_feasibility_radar.png", dpi=200, transparent=True)
plt.show()

# %% [markdown]
# # Train phase- building the actual predictive model.

# %% [markdown]
# ### Prepare features & target (drop leakage column)

# %%
# Risk_Score_0_100 directly determines Delay_Label — must exclude from features to avoid leakage


features = df_clean.drop(columns=['Delay_Label', 'Risk_Score_0_100', 'Project_ID', 'Data_Basis'])
target = df_clean['Delay_Label']


features.head()
# Out:
#           State   District       Project_Type  Land_Required_Hectare  \
# 2        Odisha  Sambalpur  Urban Development                  84.41
# 4   West Bengal    Kolkata         Irrigation                  29.96
# 5    Tamil Nadu    Madurai   National Highway                  88.53
# 11       Odisha    Cuttack   National Highway                  42.51
# 12       Odisha    Cuttack  Urban Development                  22.29
#
#     Land_Acquired_Hectare  Affected_Families  Displaced_Families  \
# 2                   33.67                164                  26
# 4                   23.30                 48                   8
# 5                   50.36                158                  35
# 11                  19.81                 83                  18
# 12                  19.25                 42                   6
#
#    Sanction_Date 3A_Notification_Date 3D_Notification_Date  ... Payment_Date  \
# 2     2018-11-25           2019-12-18           2020-09-27  ...   2026-01-06
# 4     2022-03-02           2023-01-22           2024-08-15  ...   2025-08-22
# 5     2020-08-01           2021-05-17           2023-08-06  ...   2025-03-26
# 11    2023-07-28           2025-03-10           2027-09-13  ...   2028-06-15
# 12    2016-08-12           2016-10-17           2017-04-05  ...   2022-12-07
#
#    Possession_Date Compensation_Amount_Crore  RR_Amount_Crore  \
# 2       2026-05-28                    214.35            10.61
# 4       2027-08-02                     53.02             5.04
# 5       2026-08-19                    364.77            10.93
# 11      2029-03-25                     88.51             2.42
# 12      2024-08-30                     21.13             0.94
#
#     Compensation_Status R&R_Progress_Percent  Legal_Disputes_Count  \
# 2               Pending                100.0                     4
# 4        Partially paid                 86.7                     1
# 5               Pending                 91.7                     2
# 11              Pending                 90.4                     1
# 12       Partially paid                 91.4                     0
#
#      Possession_Status Historical_Delay_Days  date_issue
# 2              Pending                  2240       False
# 4   Partial possession                  1438       False
# 5              Pending                  1284       False
# 11             Pending                  1238       False
# 12  Partial possession                  1893       False
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Handle date columns (convert to useful numeric features)

# %%
# Convert key date gaps into numeric features (days)
features['Days_Sanction_to_3A'] = (df_clean['3A_Notification_Date'] - df_clean['Sanction_Date']).dt.days
features['Days_3A_to_3D'] = (df_clean['3D_Notification_Date'] - df_clean['3A_Notification_Date']).dt.days
features['Days_3D_to_Award'] = (df_clean['Award_Date'] - df_clean['3D_Notification_Date']).dt.days
features['Days_Award_to_Payment'] = (df_clean['Payment_Date'] - df_clean['Award_Date']).dt.days
features['Days_Payment_to_Possession'] = (df_clean['Possession_Date'] - df_clean['Payment_Date']).dt.days

# Drop the raw date columns now that we've extracted useful numeric gaps
date_cols = ['Sanction_Date','3A_Notification_Date','3D_Notification_Date',
             'Award_Date','Payment_Date','Possession_Date']
features = features.drop(columns=date_cols + ['date_issue'])

features.head()
# Out:
#           State   District       Project_Type  Land_Required_Hectare  \
# 2        Odisha  Sambalpur  Urban Development                  84.41
# 4   West Bengal    Kolkata         Irrigation                  29.96
# 5    Tamil Nadu    Madurai   National Highway                  88.53
# 11       Odisha    Cuttack   National Highway                  42.51
# 12       Odisha    Cuttack  Urban Development                  22.29
#
#     Land_Acquired_Hectare  Affected_Families  Displaced_Families  \
# 2                   33.67                164                  26
# 4                   23.30                 48                   8
# 5                   50.36                158                  35
# 11                  19.81                 83                  18
# 12                  19.25                 42                   6
#
#     Compensation_Amount_Crore  RR_Amount_Crore Compensation_Status  \
# 2                      214.35            10.61             Pending
# 4                       53.02             5.04      Partially paid
# 5                      364.77            10.93             Pending
# 11                      88.51             2.42             Pending
# 12                      21.13             0.94      Partially paid
#
#     R&R_Progress_Percent  Legal_Disputes_Count   Possession_Status  \
# 2                  100.0                     4             Pending
# 4                   86.7                     1  Partial possession
# 5                   91.7                     2             Pending
# 11                  90.4                     1             Pending
# 12                  91.4                     0  Partial possession
#
#     Historical_Delay_Days  Days_Sanction_to_3A  Days_3A_to_3D  \
# 2                    2240                  388            284
# 4                    1438                  326            571
# 5                    1284                  289            811
# 11                   1238                  591            917
# 12                   1893                   66            170
#
#     Days_3D_to_Award  Days_Award_to_Payment  Days_Payment_to_Possession
# 2               1329                    598                         142
# 4                296                     76                         710
# 5                279                    319                         511
# 11               226                     50                         283
# 12              1580                    492                         632

# %% [markdown]
# ### Encode categorical columns

# %%
features_encoded = pd.get_dummies(features, columns=[
    'State', 'District', 'Project_Type', 'Compensation_Status', 'Possession_Status'
], drop_first=True)

print(features_encoded.shape)
features_encoded.head()
# Out:
# (967, 75)
#     Land_Required_Hectare  Land_Acquired_Hectare  Affected_Families  \
# 2                   84.41                  33.67                164
# 4                   29.96                  23.30                 48
# 5                   88.53                  50.36                158
# 11                  42.51                  19.81                 83
# 12                  22.29                  19.25                 42
#
#     Displaced_Families  Compensation_Amount_Crore  RR_Amount_Crore  \
# 2                   26                     214.35            10.61
# 4                    8                      53.02             5.04
# 5                   35                     364.77            10.93
# 11                  18                      88.51             2.42
# 12                   6                      21.13             0.94
#
#     R&R_Progress_Percent  Legal_Disputes_Count  Historical_Delay_Days  \
# 2                  100.0                     4                   2240
# 4                   86.7                     1                   1438
# 5                   91.7                     2                   1284
# 11                  90.4                     1                   1238
# 12                  91.4                     0                   1893
#
#     Days_Sanction_to_3A  ...  District_Varanasi  Project_Type_Irrigation  \
# 2                   388  ...              False                    False
# 4                   326  ...              False                     True
# 5                   289  ...              False                    False
# 11                  591  ...              False                    False
# 12                   66  ...              False                    False
#
#     Project_Type_National Highway  Project_Type_Railway  \
# 2                           False                 False
# 4                           False                 False
# 5                            True                 False
# 11                           True                 False
# 12                          False                 False
#
#     Project_Type_Renewable Energy  Project_Type_Urban Development  \
# 2                           False                            True
# 4                           False                           False
# 5                           False                           False
# 11                          False                           False
# 12                          False                            True
#
#     Compensation_Status_Partially paid  Compensation_Status_Pending  \
# 2                                False                         True
# 4                                 True                        False
# 5                                False                         True
# 11                               False                         True
# 12                                True                        False
#
#     Possession_Status_Pending  Possession_Status_Substantially complete
# 2                        True                                     False
# 4                       False                                     False
# 5                        True                                     False
# 11                       True                                     False
# 12                      False                                     False
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Train/test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features_encoded, target, test_size=0.2, random_state=42, stratify=target
)

print("Train size:", X_train.shape, "Test size:", X_test.shape)
# Out:
# Train size: (773, 75) Test size: (194, 75)

# %% [markdown]
# ## Train baseline model (Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %% [markdown]
# ## Evaluate

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

preds = model.predict(X_test)
probs = model.predict_proba(X_test)[:, 1]

print(classification_report(y_test, preds))
print("ROC-AUC:", roc_auc_score(y_test, probs))
print("Confusion Matrix:\n", confusion_matrix(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       156
#            1       0.87      0.87      0.87        38
#
#     accuracy                           0.95       194
#    macro avg       0.92      0.92      0.92       194
# weighted avg       0.95      0.95      0.95       194
#
# ROC-AUC: 0.980853576248313
# Confusion Matrix:
#  [[151   5]
#  [  5  33]]

# %% [markdown]
# ## Train XGBoost and compare against Random Forest

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score

xgb_model = XGBClassifier(
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    random_state=42,
    scale_pos_weight=(y_train.value_counts()[0] / y_train.value_counts()[1]),  # handles class imbalance
    eval_metric='logloss'
)
xgb_model.fit(X_train, y_train)

xgb_preds = xgb_model.predict(X_test)
xgb_probs = xgb_model.predict_proba(X_test)[:, 1]

print("--- XGBoost Results --")

print(classification_report(y_test, xgb_preds))

print("ROC-AUC:", roc_auc_score(y_test, xgb_probs))
# Out:
# --- XGBoost Results --
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95       156
#            1       0.77      0.89      0.83        38
#
#     accuracy                           0.93       194
#    macro avg       0.87      0.92      0.89       194
# weighted avg       0.93      0.93      0.93       194
#
# ROC-AUC: 0.9821187584345479

# %% [markdown]
# # SHAP-Ai Explainability

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\hp\anaconda3\lib\site-packages (0.52.0)
# Requirement already satisfied: numpy>=2 in c:\users\hp\anaconda3\lib\site-packages (from shap) (2.3.5)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\lib\site-packages (from shap) (1.7.2)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (from shap) (2.3.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\hp\anaconda3\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\hp\anaconda3\lib\site-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\hp\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\hp\anaconda3\lib\site-packages (from shap) (0.62.1)
# Requirement already satisfied: llvmlite in c:\users\hp\anaconda3\lib\site-packages (from shap) (0.45.1)
# Requirement already satisfied: cloudpickle in c:\users\hp\anaconda3\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)

# %%
import shap

explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_test)

# %%
# Global feature importance — bar chart
shap.summary_plot(shap_values, X_test, plot_type="bar", show=False)
plt.tight_layout()
plt.savefig("visuals/09_shap_feature_importance_bar.png", dpi=200, bbox_inches='tight')
plt.show()

# %%
# Detailed summary plot — shows direction of impact too

shap.summary_plot(shap_values, X_test, show=False)
plt.tight_layout()
plt.savefig("visuals/10_shap_summary_beeswarm.png", dpi=200, bbox_inches='tight')


plt.show()

# %%
# Explain ONE specific project's prediction

sample_idx = 0
shap.force_plot(
    explainer.expected_value, shap_values[sample_idx], X_test.iloc[sample_idx],
    matplotlib=True, show=False
)


plt.savefig("visuals/11_shap_force_plot_sample.png", dpi=200, bbox_inches='tight')

plt.show()

# %% [markdown]
# # Save the trained model, SHAP explainer, and feature list

# %%
import joblib
import os

os.makedirs("models", exist_ok=True)

# Save the trained model (use whichever performed better — assuming XGBoost)
joblib.dump(xgb_model, "models/risk_model.pkl")

# Save the SHAP explainer
joblib.dump(explainer, "models/shap_explainer.pkl")

# Save the exact column order/names used during training —
# your dashboard MUST feed the model data in this exact same format later
joblib.dump(list(X_train.columns), "models/feature_columns.pkl")

print("Model, explainer, and feature list saved successfully in models/ folder")
print(os.listdir("models"))
# Out:
# Model, explainer, and feature list saved successfully in models/ folder
# ['feature_columns.pkl', 'risk_model.pkl', 'shap_explainer.pkl', 'time_model.pkl']

# %%
import pandas as pd
pd.Series(xgb_probs * 100).describe()
# Out:
# count    194.000000
# mean      22.684320
# std       39.744682
# min        0.003836
# 25%        0.012454
# 50%        0.054114
# 75%       16.829056
# max       99.982628
# dtype: float64

# %%
# !pip install streamlit-folium folium
# Out:
# Requirement already satisfied: streamlit-folium in c:\users\hp\anaconda3\lib\site-packages (0.27.4)
# Requirement already satisfied: folium in c:\users\hp\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: streamlit>=1.13.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit-folium) (1.51.0)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from streamlit-folium) (3.1.6)
# Requirement already satisfied: branca in c:\users\hp\anaconda3\lib\site-packages (from streamlit-folium) (0.8.2)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\hp\anaconda3\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->streamlit-folium) (3.0.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (8.4.2)
# Requirement already satisfied: packaging<26,>=20 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (6.33.6)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (21.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\hp\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (6.5.1)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\hp\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (2.7.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit>=1.13.0->streamlit-folium) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\hp\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\hp\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->folium) (2026.1.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (0.28.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (1.17.0)

# %% [markdown]
# ## Prepare data for a regression model (predicting delay duration)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# Reuse the same features, but now predict Historical_Delay_Days (a continuous value)
# instead of the binary Delay_Label
reg_target = df_clean['Historical_Delay_Days']

# Same features_encoded from before, since we already dropped Risk_Score_0_100 and Delay_Label
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    features_encoded, reg_target, test_size=0.2, random_state=42
)

# %% [markdown]
# ### Train the regression model

# %%
time_model = RandomForestRegressor(n_estimators=200, random_state=42)
time_model.fit(X_train_reg, y_train_reg)

time_preds = time_model.predict(X_test_reg)

print("MAE (days):", mean_absolute_error(y_test_reg, time_preds))
print("R² Score:", r2_score(y_test_reg, time_preds))
# Out:
# MAE (days): 3.1310309278350554
# R² Score: 0.9999049049192514

# %% [markdown]
# ### Save this new model too

# %%
joblib.dump(time_model, "models/time_model.pkl")
print("Time prediction model saved")
# Out:
# Time prediction model saved

# %%
# Check if Historical_Delay_Days is just the sum of our engineered date-gap features
date_gap_sum = (
    features_encoded['Days_Sanction_to_3A'] +
    features_encoded['Days_3A_to_3D'] +
    features_encoded['Days_3D_to_Award'] +
    features_encoded['Days_Award_to_Payment'] +
    features_encoded['Days_Payment_to_Possession']
)

correlation = date_gap_sum.corr(df_clean['Historical_Delay_Days'])
print("Correlation between date-gap sum and Historical_Delay_Days:", correlation)

# Also check a few actual values side by side
comparison = pd.DataFrame({
    'Sum_of_Gaps': date_gap_sum,
    'Historical_Delay_Days': df_clean['Historical_Delay_Days'].values
}).head(10)
print(comparison)
# Out:
# Correlation between date-gap sum and Historical_Delay_Days: 0.9394627428181335
#     Sum_of_Gaps  Historical_Delay_Days
# 2          2741                   2240
# 4          1979                   1438
# 5          2209                   1284
# 11         2067                   1238
# 12         2940                   1893
# 13         1150                     36
# 15         3151                   2507
# 17         2379                   1576
# 22         2447                   1706
# 23         2164                   1088

# %%
# Drop the date-gap features that likely compose the target
leak_prone_cols = ['Days_Sanction_to_3A', 'Days_3A_to_3D', 'Days_3D_to_Award',
                    'Days_Award_to_Payment', 'Days_Payment_to_Possession']

features_encoded_no_leak = features_encoded.drop(columns=leak_prone_cols)

X_train_reg2, X_test_reg2, y_train_reg2, y_test_reg2 = train_test_split(
    features_encoded_no_leak, reg_target, test_size=0.2, random_state=42
)

time_model = RandomForestRegressor(n_estimators=200, random_state=42)
time_model.fit(X_train_reg2, y_train_reg2)

time_preds2 = time_model.predict(X_test_reg2)
print("MAE (days):", mean_absolute_error(y_test_reg2, time_preds2))
print("R² Score:", r2_score(y_test_reg2, time_preds2))
# Out:
# MAE (days): 2.648556701030939
# R² Score: 0.9999369948003372

# %%
# Drop the date-gap features that likely compose the target
leak_prone_cols = ['Days_Sanction_to_3A', 'Days_3A_to_3D', 'Days_3D_to_Award',
                    'Days_Award_to_Payment', 'Days_Payment_to_Possession']

features_encoded_no_leak = features_encoded.drop(columns=leak_prone_cols)

X_train_reg2, X_test_reg2, y_train_reg2, y_test_reg2 = train_test_split(
    features_encoded_no_leak, reg_target, test_size=0.2, random_state=42
)

time_model = RandomForestRegressor(n_estimators=200, random_state=42)
time_model.fit(X_train_reg2, y_train_reg2)

time_preds2 = time_model.predict(X_test_reg2)
print("MAE (days):", mean_absolute_error(y_test_reg2, time_preds2))
print("R² Score:", r2_score(y_test_reg2, time_preds2))
# Out:
# MAE (days): 2.648556701030939
# R² Score: 0.9999369948003372

# %%
print('Risk_Score_0_100' in features_encoded_no_leak.columns)
print('Historical_Delay_Days' in features_encoded_no_leak.columns)
# Out:
# False
# True

# %%
fccc
