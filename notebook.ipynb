# %%
# kiran in ONN

# %%
import pandas as pd

# %%
df = pd.read_excel("BhuNirvighna_Land_Acquisition_Dataset.xlsx")

# %%
df.head()
# Out:
#    Project_ID           State   District       Project_Type  \
# 0  BHNV-00001     West Bengal    Hooghly         Irrigation
# 1  BHNV-00002  Madhya Pradesh     Ujjain  Urban Development
# 2  BHNV-00003          Odisha  Sambalpur  Urban Development
# 3  BHNV-00004         Gujarat  Ahmedabad            Railway
# 4  BHNV-00005     West Bengal    Kolkata         Irrigation
#
#    Land_Required_Hectare  Land_Acquired_Hectare  Affected_Families  \
# 0                 169.36                 107.95                304
# 1                  60.51                  57.81                 94
# 2                  84.41                  33.67                164
# 3                  68.02                  46.03                129
# 4                  29.96                  23.30                 48
#
#    Displaced_Families Sanction_Date 3A_Notification_Date  ...  \
# 0                  50    2019-05-03           2019-08-29  ...
# 1                  15    2021-04-29           2023-02-26  ...
# ...

# %%
df.shape
# Out:
# (2000, 24)

# %%
df.to_csv("BhuNirvighna_Land_Acquisition_Dataset.csv", index=False)

# %%
check = pd.read_csv("BhuNirvighna_Land_Acquisition_Dataset.csv")
check.head()
# Out:
#    Project_ID           State   District       Project_Type  \
# 0  BHNV-00001     West Bengal    Hooghly         Irrigation
# 1  BHNV-00002  Madhya Pradesh     Ujjain  Urban Development
# 2  BHNV-00003          Odisha  Sambalpur  Urban Development
# 3  BHNV-00004         Gujarat  Ahmedabad            Railway
# 4  BHNV-00005     West Bengal    Kolkata         Irrigation
#
#    Land_Required_Hectare  Land_Acquired_Hectare  Affected_Families  \
# 0                 169.36                 107.95                304
# 1                  60.51                  57.81                 94
# 2                  84.41                  33.67                164
# 3                  68.02                  46.03                129
# 4                  29.96                  23.30                 48
#
#    Displaced_Families Sanction_Date 3A_Notification_Date  ...  \
# 0                  50    2019-05-03           2019-08-29  ...
# 1                  15    2021-04-29           2023-02-26  ...
# ...

# %%
df = pd.read_excel(r"C:\Users\YourName\Downloads\BhuNirvighna_Land_Acquisition_Dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_excel(r"C:\Users\YourName\Downloads\BhuNirvighna_Land_Acquisition_Dataset.xlsx")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
# !pip install openpyxl
